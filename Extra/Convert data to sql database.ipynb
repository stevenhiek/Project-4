# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
az_restaurants = pd.read_csv("../Resources/az_yelp_restaurants.csv")

# %%
topten = pd.read_csv("../Resources/top10_restaurants.csv")

# %%
az_restaurants = pd.read_json("../Resources/az_yelp_restaurants.json")
az_restaurants
# Out:
#                                      name                          address  \
# 0                            "McDonald's"           "719 E Thunderbird Rd"
# 1          "Charr An American Burger Bar"  "777 E Thunderbird Rd, Ste 107"
# 2                            "McDonald's"            "1635 E Camelback Rd"
# 3                  "Little Caesars Pizza"           "10720 E Southern Ave"
# 4                       "Caviness Studio"                               ""
# ...                                   ...                              ...
# 10581           "Yin's Chinese Resturant"        "1950 W Indian School Rd"
# 10582           "Escobar Mexican Kitchen"    "1219 E Glendale Ave, Ste 14"
# 10583                      "Zorbas Grill"                "440 W Warner Rd"
# 10584  "Salt & Lime Modern Mexican Grill"      "9397 E Shea Blvd, Ste 115"
# 10585         "Floridino's Pizza & Pasta"   "590 N Alma School Rd, Ste 35"
#
#              city state  postal_code   latitude   longitude  stars  \
# 0         Phoenix    AZ        85022  33.607070 -112.064382    1.0
# 1         Phoenix    AZ        85022  33.607310 -112.063404    3.0
# 2         Phoenix    AZ        85016  33.508765 -112.046240    3.0
# 3            Mesa    AZ        85209  33.394877 -111.600194    2.5
# 4         Phoenix    AZ        85001  33.449967 -112.070222    5.0
# ...           ...   ...          ...        ...         ...    ...
# 10581     Phoenix    AZ        85015  33.495582 -112.101711    4.0
# 10582     Phoenix    AZ        85020  33.537893 -112.055100    4.5
# 10583       Tempe    AZ        85284  33.335099 -111.944597    2.5
# 10584  Scottsdale    AZ        85260  33.581511 -111.879218    3.5
# 10585    Chandler    AZ        85224  33.311383 -111.859604    4.0
#
#        review_count                                         categories
# 0                10                      Fast Food;Burgers;Restaurants
# 1               232                                Burgers;Restaurants
# 2                34                      Restaurants;Burgers;Fast Food
# 3                 4                                  Restaurants;Pizza
# 4                 4  Marketing;Men's Clothing;Restaurants;Graphic D...
# ...             ...                                                ...
# 10581            38                                Restaurants;Chinese
# 10582           132            Food;Mexican;Restaurants;Specialty Food
# 10583             3                    Mediterranean;Greek;Restaurants
# 10584           223  Salad;Food;Beer;Wine & Spirits;Restaurants;Mex...
# 10585           374  Pizza;Event Planning & Services;Italian;Catere...
#
# [10586 rows x 10 columns]

# %%
rds_connection_string = "postgres:postgres@localhost:5432/restaurants_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
topten.to_sql(name='topten', con=engine, if_exists='append', index=False)

# %%
topten = pd.read_sql_query('select * from topten', con=engine)

# %%
az_restaurants.to_sql(name='az_restaurants', con=engine, if_exists='append', index=False)

# %%
az_restaurants_csv = pd.read_sql_query('select * from az_restaurants', con=engine)
az_restaurants_csv = az_restaurants_csv.drop(['index'],axis=1)

# %%
az_restaurants_csv.to_csv("../Resources/az_yelp_restaurants.csv",index=False)
